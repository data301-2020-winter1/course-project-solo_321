# %%
import pandas as pd

df_logistic_water = pd.read_csv('../data/raw/202042bitacora_agua.csv', encoding = "ISO-8859-1", header = 0)
df_logistic_water

df_logistic_soda = pd.read_csv('../data/raw/202042bitacora_gaseosa.csv', encoding = "ISO-8859-1", header = 0)
df_logistic_soda

df_cocacola = pd.read_csv('../data/raw/202042nomina.csv', encoding = "ISO-8859-1", header = 0)
df_cocacola
# Out:
#           fecha     remision                               origen  \
# 0    12/10/2020  01R71101341  01 - PLANTA SOYAPANGO
# 1    12/10/2020  14R70236515  14 - NIXAPA
# 2    12/10/2020  92R70010487  92 - OPERADOR LOGISTICO
# 3    13/10/2020  01R71101316  01 - PLANTA SOYAPANGO
# 4    13/10/2020  08R70013437  08 - PASATIEMPO
# ..          ...          ...                                  ...
# 941  17/10/2020  14R70236752  14 - NIXAPA
# 942  17/10/2020  14R70236782  14 - NIXAPA
# 943  17/10/2020  14R70236800  14 - NIXAPA
# 944  17/10/2020  92R70010524  92 - OPERADOR LOGISTICO
# 945  18/10/2020  01R71101869  01 - PLANTA SOYAPANGO
#
#                                  desitno      placa  kilometros
# 0    14 - NIXAPA                          C-119-111        24.0
# 1    92 - OPERADOR LOGISTICO              C-119-111        19.0
# 2    01 - PLANTA SOYAPANGO                C-119-111        18.0
# 3    31 - DISTR. AGUA Y JUGO              C-119-111         4.0
# ...
